# %%
import pandas as pd
import overpy

# %%
df = pd.read_csv("../bicikelj_postaje.csv")

# %%
df.head()
# Out:
#    number contract_name                               name  \
# 0      59     ljubljana                      LIDL BEŽIGRAD
# 1      54     ljubljana                    ŠMARTINSKI PARK
# 2      45     ljubljana  SAVSKO NASELJE 1-ŠMARTINSKA CESTA
# 3      68     ljubljana                             ČRNUČE
# 4      11     ljubljana                   VILHARJEVA CESTA
#
#                address  banking  bonus  bike_stands  available_bike_stands  \
# 0          Bežigrad 11    False  False           20                     19
# 1  Smartinska cesta 58    False  False           20                      7
# 2       Savska cesta 1    False  False           20                     20
# 3       Dunajska cesta    False  False           20                     17
# 4  Vilharjeva cesta 23    False  False           20                      2
#
#    available_bikes status    last_update  position_lat  position_lon
# 0                1   OPEN  1702663056000     46.063797     14.506854
# 1               13   OPEN  1702663132000     46.065206     14.529911
# 2                0   OPEN  1702663157000     46.062475     14.524321
# 3                3   OPEN  1702662921000     46.102446     14.530213
# 4               18   OPEN  1702663070000     46.060050     14.513020

# %%
def num_bus_stations(lat, lon):
    """
    Find number of bus stations in radius 500 meters.
    """
    api = overpy.Overpass()
    query = f"""
            (
            node(around:500,{lat},{lon});
            );out;
            """.format(lat=...,lon=...)    
    result = api.query(query)
    n_nodes = len(result.nodes)
    # print(n_nodes)

    counter = 0
    tags = []
    lpp = []
    for node in result.nodes:
        if node.tags:
            counter += 1
            tags.append(node.tags)

    for t in tags:
        if 'bus_stop' in list(t.keys()) or 'bus_stop' in list(t.values()):
            lpp.append(t)
    return len(lpp)

# %%
# test za FMF
lat = 46.042372
lon = 14.490436
cnt = num_bus_stations(lat, lon)
print(cnt)

# bavarski dvor
lat = 46.104820
lon = 14.442480
lat, lon = 46.05682,14.50551
cnt = num_bus_stations(lat, lon)
print(cnt)
# Out:
# 6
# 15

# %%
df['num_bus_stations'] = df.apply(lambda row: num_bus_stations(row['position_lat'], row['position_lon']), axis=1)

# %%
df.head()
# Out:
#    number contract_name                               name  \
# 0      59     ljubljana                      LIDL BEŽIGRAD
# 1      54     ljubljana                    ŠMARTINSKI PARK
# 2      45     ljubljana  SAVSKO NASELJE 1-ŠMARTINSKA CESTA
# 3      68     ljubljana                             ČRNUČE
# 4      11     ljubljana                   VILHARJEVA CESTA
#
#                address  banking  bonus  bike_stands  available_bike_stands  \
# 0          Bežigrad 11    False  False           20                     19
# 1  Smartinska cesta 58    False  False           20                      7
# 2       Savska cesta 1    False  False           20                     20
# 3       Dunajska cesta    False  False           20                     17
# 4  Vilharjeva cesta 23    False  False           20                      2
#
#    available_bikes status    last_update  position_lat  position_lon  \
# 0                1   OPEN  1702663056000     46.063797     14.506854
# 1               13   OPEN  1702663132000     46.065206     14.529911
# 2                0   OPEN  1702663157000     46.062475     14.524321
# 3                3   OPEN  1702662921000     46.102446     14.530213
# 4               18   OPEN  1702663070000     46.060050     14.513020
#
#    num_bus_stations
# 0                13
# 1                16
# 2                11
# 3                 7
# 4                13

# %%
df.to_csv("bicikelj_postaje.csv")
df.rename(columns={'name': 'station'}, inplace=True)
df.head()
# Out:
#    number contract_name                            station  \
# 0      59     ljubljana                      LIDL BEŽIGRAD
# 1      54     ljubljana                    ŠMARTINSKI PARK
# 2      45     ljubljana  SAVSKO NASELJE 1-ŠMARTINSKA CESTA
# 3      68     ljubljana                             ČRNUČE
# 4      11     ljubljana                   VILHARJEVA CESTA
#
#                address  banking  bonus  bike_stands  available_bike_stands  \
# 0          Bežigrad 11    False  False           20                     19
# 1  Smartinska cesta 58    False  False           20                      7
# 2       Savska cesta 1    False  False           20                     20
# 3       Dunajska cesta    False  False           20                     17
# 4  Vilharjeva cesta 23    False  False           20                      2
#
#    available_bikes status    last_update  position_lat  position_lon  \
# 0                1   OPEN  1702663056000     46.063797     14.506854
# 1               13   OPEN  1702663132000     46.065206     14.529911
# 2                0   OPEN  1702663157000     46.062475     14.524321
# 3                3   OPEN  1702662921000     46.102446     14.530213
# 4               18   OPEN  1702663070000     46.060050     14.513020
#
#    num_bus_stations
# 0                13
# 1                16
# 2                11
# 3                 7
# 4                13

# %%
preprocessed_data = pd.read_csv("../data/data/bicikelj_preprocessed.csv")

# %%
preprocessed_data.head()
# Out:
#    Unnamed: 0            timestamp                 station  target  \
# 0           0  2022-08-02 13:35:00  ALEJA - CELOVŠKA CESTA       1
# 1           1  2022-08-02 13:44:00  ALEJA - CELOVŠKA CESTA       0
# 2           2  2022-08-02 13:55:00  ALEJA - CELOVŠKA CESTA       0
# 3           3  2022-08-02 14:05:00  ALEJA - CELOVŠKA CESTA       1
# 4           4  2022-08-02 14:15:00  ALEJA - CELOVŠKA CESTA       2
#
#    time_of_day_sin  time_of_day_cos  temperature  precipitation  snow_depth  \
# 0        -0.402747        -0.915311         14.9            0.0         0.0
# 1        -0.438371        -0.898794         14.9            0.0         0.0
# 2        -0.480989        -0.876727         14.9            0.0         0.0
# 3        -0.518773        -0.854912         14.9            0.0         0.0
# 4        -0.555570        -0.831470         14.9            0.0         0.0
#
#    cloud_cover  ...  bonus  bike_stands  available_bike_stands  \
# 0         31.0  ...  False           20                      9
# 1         31.0  ...  False           20                      9
# 2         31.0  ...  False           20                      9
# 3         31.0  ...  False           20                      9
# 4         31.0  ...  False           20                      9
#
#    available_bikes status    last_update  position_lat  position_lon  \
# 0               11   OPEN  1702663252000     46.077302     14.482581
# 1               11   OPEN  1702663252000     46.077302     14.482581
# 2               11   OPEN  1702663252000     46.077302     14.482581
# 3               11   OPEN  1702663252000     46.077302     14.482581
# 4               11   OPEN  1702663252000     46.077302     14.482581
#
#    distance_to_center  is_weekend
# 0             3.39777       False
# 1             3.39777       False
# 2             3.39777       False
# 3             3.39777       False
# 4             3.39777       False
#
# [5 rows x 37 columns]

# %%
new_preprocessed_data = pd.merge(preprocessed_data, df, on='station', how='left')

# %%
new_preprocessed_data.head()
# Out:
#    Unnamed: 0            timestamp                 station  target  \
# 0           0  2022-08-02 13:35:00  ALEJA - CELOVŠKA CESTA       1
# 1           1  2022-08-02 13:44:00  ALEJA - CELOVŠKA CESTA       0
# 2           2  2022-08-02 13:55:00  ALEJA - CELOVŠKA CESTA       0
# 3           3  2022-08-02 14:05:00  ALEJA - CELOVŠKA CESTA       1
# 4           4  2022-08-02 14:15:00  ALEJA - CELOVŠKA CESTA       2
#
#    time_of_day_sin  time_of_day_cos  temperature  precipitation  snow_depth  \
# 0        -0.402747        -0.915311         14.9            0.0         0.0
# 1        -0.438371        -0.898794         14.9            0.0         0.0
# 2        -0.480989        -0.876727         14.9            0.0         0.0
# 3        -0.518773        -0.854912         14.9            0.0         0.0
# 4        -0.555570        -0.831470         14.9            0.0         0.0
#
#    cloud_cover  ...  banking_y  bonus_y  bike_stands_y  \
# 0         31.0  ...      False    False             20
# 1         31.0  ...      False    False             20
# 2         31.0  ...      False    False             20
# 3         31.0  ...      False    False             20
# 4         31.0  ...      False    False             20
#
#    available_bike_stands_y available_bikes_y  status_y  last_update_y  \
# 0                        9                11      OPEN  1702663252000
# 1                        9                11      OPEN  1702663252000
# 2                        9                11      OPEN  1702663252000
# 3                        9                11      OPEN  1702663252000
# 4                        9                11      OPEN  1702663252000
#
#    position_lat_y  position_lon_y  num_bus_stations
# 0       46.077302       14.482581                10
# 1       46.077302       14.482581                10
# 2       46.077302       14.482581                10
# 3       46.077302       14.482581                10
# 4       46.077302       14.482581                10
#
# [5 rows x 50 columns]

# %%
new_preprocessed_data.to_csv("../data/data/bicikelj_preprocessed_new.csv")
